# %% [markdown]
# <a href="https://colab.research.google.com/github/gmxavier/TEP-meets-LSTM/blob/master/Using-tep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Under construction 🚧

# %%
# to use R
# !pip install rpy2
# %load_ext rpy2.ipython
# Out:
# ...
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# to get the tep.R file
from requests import get
url = 'https://raw.githubusercontent.com/gmxavier/TEP-meets-LSTM/master/tep/R/tep.R'
r = get(url)
with open('tep.R', 'w') as f: 
  f.write(r.text)

# %%
# %%R
# source('./tep.R')
# ls(all.names = TRUE)
# Out:
# [1] "tep"       "tepAttrib"

# %%
# %%R
# tepAttrib()
# Out:
#       variable    description                                unit
#  [1,] "XMEAS(1)"  "A Feed (stream 1)"                        "kscmh"
#  [2,] "XMEAS(2)"  "D Feed (stream 2)"                        "kg h-1"
#  [3,] "XMEAS(3)"  "E Feed (stream 3)"                        "kg h-1"
#  [4,] "XMEAS(4)"  "A and C Feed (stream 4)"                  "kscmh"
#  [5,] "XMEAS(5)"  "Recycle Flow (stream 8)"                  "kscmh"
#  [6,] "XMEAS(6)"  "Reactor Feed Rate"                        "kscmh"
#  [7,] "XMEAS(7)"  "Reactor Pressure"                         "kPa"
#  [8,] "XMEAS(8)"  "Reactor Level"                            "%"
#  [9,] "XMEAS(9)"  "Reactor Temperature"                      "oC"
# [10,] "XMEAS(10)" "Purge Rate (stream 9)"                    "kscmh"
# [11,] "XMEAS(11)" "Product Sep Temp"                         "oC"
# [12,] "XMEAS(12)" "Product Sep Level"                        "%"
# [13,] "XMEAS(13)" "Prod Sep Pressure"                        "kPa"
# ...

# %%
# to get the temain.f file
url = 'https://raw.githubusercontent.com/gmxavier/TEP-meets-LSTM/master/tep/src/temain.f'
r = get(url)
with open('temain.f', 'w') as f: 
  f.write(r.text)

# to get the teprob.f file
url = 'https://raw.githubusercontent.com/gmxavier/TEP-meets-LSTM/master/tep/src/teprob.f'
r = get(url)
with open('teprob.f', 'w') as f: 
  f.write(r.text)

# to compile the temain.f
# !gcc -fPIC -c teprob.f
# !gcc -fPIC -shared -o temain.so temain.f teprob.o -lm -lc

# %%
# !ls
# Out:
# sample_data  temain.f  temain.so  tep.R  teprob.f  teprob.o

# %%
# everything seens to be ok until here, but when we try to load the shared object, something unexpected happens
# %%R
dyn.load('temain.so')
# Out:
# R[write to console]: Error in dyn.load("temain.so") :
#   unable to load shared object '/content/temain.so':
#   /content/temain.so: undefined symbol: _gfortran_st_write_done
# Error in dyn.load("temain.so") :
#   unable to load shared object '/content/temain.so':
#   /content/temain.so: undefined symbol: _gfortran_st_write_done
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/rpy2/ipython/rmagic.py in eval(self, code)
#     267                 # Need the newline in case the last line in code is a comment.
# --> 268                 value, visible = ro.r("withVisible({%s\n})" % code)
#     269             except (ri.embedded.RRuntimeError, ValueError) as exception:
#
# /usr/local/lib/python3.7/dist-packages/rpy2/robjects/__init__.py in __call__(self, string)
#     437         p = rinterface.parse(string)
# ...
